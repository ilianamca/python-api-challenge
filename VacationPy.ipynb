# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests



# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0  edinburgh of the seven seas -37.0676  -12.3116     49.91
# 1        1                   bredasdorp -34.5322   20.0403     54.64
# 2        2                     bilibino  68.0546  166.4372     22.96
# 3        3                   constantia  44.1833   28.6500     52.70
# 4        4                       bethel  41.3712  -73.4140     61.65
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        59          78       21.39      SH  1696304844
# 1        95           4        4.21      ZA  1696304844
# 2        95          90        2.01      RU  1696304844
# 3        57           1        8.43      RO  1696304845
# 4        88           0        3.44      US  1696304762

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
humid_city = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = "EsriUSATopo",
    frame_width = 700,
    frame_height = 500,
    size = 'Humidity',
    color = 'City',
    alpha = 0.7
)

# Display the map
humid_city
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\util.py:230, in process_crs(crs)
#     229 try:
# --> 230     import cartopy.crs as ccrs
#     231     import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\ilian\OneDrive\Desktop\BC Work\python-api-challenge\Starter_Code\starter_code\VacationPy.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Configure the map plot
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> humid_city = city_data_df.hvplot.points(
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     'Lng',
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     'Lat',
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     geo = True,
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>     tiles = "EsriUSATopo",
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     frame_width = 700,
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a>     frame_height = 500,
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a>     size = 'Humidity',
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a>     color = 'City',
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a>     alpha = 0.7
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> # Display the map
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> humid_city
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\plotting\core.py:1612, in hvPlotTabular.points(self, x, y, **kwds)
#    1554 def points(self, x=None, y=None, **kwds):
#    1555     """
#    1556     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1557     geographic plots.
#    (...)
#    1610     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1611     """
# -> 1612     return self(x, y, kind="points", **kwds)
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\plotting\core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\plotting\core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\converter.py:396, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394 self.dynamic = dynamic
#     395 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396 self.crs = self._process_crs(data, crs) if self.geo else None
#     397 self.project = project
#     398 self.coastline = coastline
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\converter.py:650, in HoloViewsConverter._process_crs(self, data, crs)
#     647     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     649 try:
# --> 650     return process_crs(_crs)
#     651 except ValueError:
#     652     # only raise error if crs was specified in kwargs
#     653     if crs:
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\util.py:234, in process_crs(crs)
#     232     import pyproj
#     233 except ImportError:
# --> 234     raise ImportError('Geographic projection support requires GeoViews, pyproj and cartopy.')
#     236 if crs is None:
#     237     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires GeoViews, pyproj and cartopy.

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

clean_df = city_data_df.loc[city_data_df['Max Temp'] <= 40]

# Drop any rows with null values

clean_df = clean_df.dropna()

# Display sample data
clean_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 2          2           bilibino  68.0546  166.4372     22.96        95
# 11        11          vorgashor  67.5833   63.9500     34.07        80
# 15        15              tiksi  71.6872  128.8694     28.20        83
# 18        18     puerto natales -51.7236  -72.4875     37.42        95
# 22        22          ilulissat  69.2167  -51.1000     26.62        36
# 25        25           qaqortoq  60.7167  -46.0333     37.29        90
# 34        34        monchegorsk  67.9397   32.8739     37.76        98
# 37        37  port-aux-francais -49.3500   70.2167     36.39        80
# 45        45           ust-nera  64.5667  143.2000     35.22        68
# 48        48          grytviken -54.2811  -36.5092     33.66        65
# 52        52          iskateley  67.6803   53.1512     39.02        78
# 53        53            college  64.8569 -147.8028     37.38        65
# 55        55        olonkinbyen  70.9221   -8.7187     37.27        89
# 59        59    verkhnevilyuysk  63.4453  120.3167     30.94        77
# 70        70          polyarnyy  69.1989   33.4478     35.40        76
# 77        77            iqaluit  63.7506  -68.5145     37.13        86
# 92        92         labytnangi  66.6572   66.4183     36.05        67
# 93        93            dudinka  69.4058   86.1778     34.63        96
# 97        97       longyearbyen  78.2186   15.6401     26.44        63
# 101      101         novodvinsk  64.4165   40.8122     37.78        84
# 136      136              lensk  60.7253  114.9278     30.72        73
# 140      140             anadyr  64.7500  177.4833     39.70        48
# 160      160            aasiaat  68.7098  -52.8699     14.77        79
# 169      169             badger  64.8000 -147.5333     37.31        67
# 170      170            susuman  62.7833  148.1667     34.99        61
# 174      174         gadzhiyevo  69.2551   33.3362     34.57        78
# 197      197         isafjordur  66.0755  -23.1240     33.91        93
# 206      206            udachny  66.4167  112.4000     25.45        73
# 214      214           sisimiut  66.9395  -53.6735     33.10        60
# 220      220           vilyuysk  63.7553  121.6247     36.66        51
# 233      233       arkhangel'sk  64.5401   40.5433     38.12        84
# 248      248            markovo  57.3206  107.0881     34.32        69
# 258      258       puerto aysen -45.4000  -72.7000     36.93        99
# 267      267         kosh-agach  50.0000   88.6667     39.24        60
# 324      324            alzamay  55.5562   98.6644     38.03        97
# 351      351        egilsstadir  65.2653  -14.3948     39.11        93
# 354      354            kirensk  57.7853  108.1119     36.01        65
# 375      375            talnakh  69.4865   88.3972     34.21        96
# 418      418             tromso  69.6496   18.9570     37.42        87
# 449      449        nar'yan-mar  67.6713   53.0870     39.11        78
# 450      450    severobaykal'sk  55.6500  109.3167     37.51        43
# 452      452           tazovsky  67.4667   78.7000     39.54        94
# 460      460              vadso  70.0744   29.7487     32.88       100
# 522      522           usogorsk  63.4106   48.6872     38.66        90
# 530      530          zhigalovo  54.8097  105.1578     35.08        56
# 548      548       saudarkrokur  65.7461  -19.6394     37.65        97
# 565      565           motygino  58.1831   94.7592     38.79        54
# 569      569           lycksele  64.5954   18.6735     33.67       100
#
#      Cloudiness  Wind Speed Country        Date
# 2            90        2.01      RU  1696304844
# 11           57       17.83      RU  1696304846
# 15           87       16.84      RU  1696304846
# 18          100        4.63      CL  1696304847
# 22            0       21.85      GL  1696304847
# 25          100        3.49      GL  1696304848
# 34          100        6.60      RU  1696304743
# 37           71       32.50      TF  1696304850
# 45           27        3.00      RU  1696304851
# 48           98       10.36      GS  1696304852
# 52           62       21.00      RU  1696304852
# 53           20       13.80      US  1696304852
# 55           76       15.21      SJ  1696304853
# 59           70        4.00      RU  1696304853
# 70          100        6.44      RU  1696304855
# 77          100       11.99      CA  1696304856
# 92           16       15.59      RU  1696304859
# 93          100       23.00      RU  1696304859
# 97           75       16.11      SJ  1696304860
# 101         100        8.03      RU  1696304860
# 136          96        8.99      RU  1696304867
# 140           0        8.95      RU  1696304867
# 160          20        8.81      GL  1696304871
# 169          40       13.80      US  1696304872
# 170           7        4.00      RU  1696304873
# 174         100        6.53      RU  1696304873
# 197         100       15.73      IS  1696304877
# 206          45       11.43      RU  1696304850
# 214           3        5.14      GL  1696304880
# 220          43        5.61      RU  1696304881
# 233         100        8.32      RU  1696304883
# 248          94        9.98      RU  1696304886
# 258         100        2.66      CL  1696304887
# 267           6        2.35      RU  1696304889
# 324         100        5.66      RU  1696304898
# 351         100        6.91      IS  1696304903
# 354          95       10.00      RU  1696304903
# 375         100       15.32      RU  1696304907
# 418          75        2.30      NO  1696304915
# 449          62       21.00      RU  1696304921
# 450          51        4.85      RU  1696304921
# 452         100       23.87      RU  1696304921
# 460         100        5.75      NO  1696304923
# 522         100        2.80      RU  1696304934
# 530          95        3.00      RU  1696304935
# 548         100        6.20      IS  1696304938
# 565         100       10.00      RU  1696304940
# 569          75        2.30      SE  1696304941

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = clean_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
# C:\Users\ilian\AppData\Local\Temp\ipykernel_18580\1385115104.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ''
#                   City Country      Lat       Lng  Humidity Hotel Name
# 2             bilibino      RU  68.0546  166.4372        95
# 11           vorgashor      RU  67.5833   63.9500        80
# 15               tiksi      RU  71.6872  128.8694        83
# 18      puerto natales      CL -51.7236  -72.4875        95
# 22           ilulissat      GL  69.2167  -51.1000        36
# 25            qaqortoq      GL  60.7167  -46.0333        90
# 34         monchegorsk      RU  67.9397   32.8739        98
# 37   port-aux-francais      TF -49.3500   70.2167        80
# 45            ust-nera      RU  64.5667  143.2000        68
# 48           grytviken      GS -54.2811  -36.5092        65
# 52           iskateley      RU  67.6803   53.1512        78
# 53             college      US  64.8569 -147.8028        65
# 55         olonkinbyen      SJ  70.9221   -8.7187        89
# 59     verkhnevilyuysk      RU  63.4453  120.3167        77
# 70           polyarnyy      RU  69.1989   33.4478        76
# 77             iqaluit      CA  63.7506  -68.5145        86
# 92          labytnangi      RU  66.6572   66.4183        67
# 93             dudinka      RU  69.4058   86.1778        96
# 97        longyearbyen      SJ  78.2186   15.6401        63
# 101         novodvinsk      RU  64.4165   40.8122        84
# 136              lensk      RU  60.7253  114.9278        73
# 140             anadyr      RU  64.7500  177.4833        48
# 160            aasiaat      GL  68.7098  -52.8699        79
# 169             badger      US  64.8000 -147.5333        67
# 170            susuman      RU  62.7833  148.1667        61
# 174         gadzhiyevo      RU  69.2551   33.3362        78
# 197         isafjordur      IS  66.0755  -23.1240        93
# 206            udachny      RU  66.4167  112.4000        73
# 214           sisimiut      GL  66.9395  -53.6735        60
# 220           vilyuysk      RU  63.7553  121.6247        51
# 233       arkhangel'sk      RU  64.5401   40.5433        84
# 248            markovo      RU  57.3206  107.0881        69
# 258       puerto aysen      CL -45.4000  -72.7000        99
# 267         kosh-agach      RU  50.0000   88.6667        60
# 324            alzamay      RU  55.5562   98.6644        97
# 351        egilsstadir      IS  65.2653  -14.3948        93
# 354            kirensk      RU  57.7853  108.1119        65
# 375            talnakh      RU  69.4865   88.3972        96
# 418             tromso      NO  69.6496   18.9570        87
# 449        nar'yan-mar      RU  67.6713   53.0870        78
# 450    severobaykal'sk      RU  55.6500  109.3167        43
# 452           tazovsky      RU  67.4667   78.7000        94
# 460              vadso      NO  70.0744   29.7487       100
# 522           usogorsk      RU  63.4106   48.6872        90
# 530          zhigalovo      RU  54.8097  105.1578        56
# 548       saudarkrokur      IS  65.7461  -19.6394        97
# 565           motygino      RU  58.1831   94.7592        54
# 569           lycksele      SE  64.5954   18.6735       100

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 #10,000 meters
params = {
    "categories": "accommodation.hotel",
    'apiKey': geoapify_key,
    "limit": 1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = hotel_df.loc[index, 'Lat']
    lon = hotel_df.loc[index, 'Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# bilibino - nearest hotel: No hotel found
# vorgashor - nearest hotel: No hotel found
# tiksi - nearest hotel: No hotel found
# puerto natales - nearest hotel: No hotel found
# ilulissat - nearest hotel: No hotel found
# qaqortoq - nearest hotel: No hotel found
# monchegorsk - nearest hotel: No hotel found
# port-aux-francais - nearest hotel: No hotel found
# ust-nera - nearest hotel: No hotel found
# grytviken - nearest hotel: No hotel found
# iskateley - nearest hotel: No hotel found
# college - nearest hotel: No hotel found
# olonkinbyen - nearest hotel: No hotel found
# 197         isafjordur      IS  66.0755  -23.1240        93  No hotel found
# 206            udachny      RU  66.4167  112.4000        73  No hotel found
# 214           sisimiut      GL  66.9395  -53.6735        60  No hotel found
# 220           vilyuysk      RU  63.7553  121.6247        51  No hotel found
# 233       arkhangel'sk      RU  64.5401   40.5433        84  No hotel found
# 248            markovo      RU  57.3206  107.0881        69  No hotel found
# 258       puerto aysen      CL -45.4000  -72.7000        99  No hotel found
# 267         kosh-agach      RU  50.0000   88.6667        60  No hotel found
# 324            alzamay      RU  55.5562   98.6644        97  No hotel found
# 351        egilsstadir      IS  65.2653  -14.3948        93  No hotel found
# 354            kirensk      RU  57.7853  108.1119        65  No hotel found
# 375            talnakh      RU  69.4865   88.3972        96  No hotel found
# 418             tromso      NO  69.6496   18.9570        87  No hotel found
# 449        nar'yan-mar      RU  67.6713   53.0870        78  No hotel found
# 450    severobaykal'sk      RU  55.6500  109.3167        43  No hotel found
# 452           tazovsky      RU  67.4667   78.7000        94  No hotel found
# 460              vadso      NO  70.0744   29.7487       100  No hotel found
# 522           usogorsk      RU  63.4106   48.6872        90  No hotel found
# 530          zhigalovo      RU  54.8097  105.1578        56  No hotel found
# 548       saudarkrokur      IS  65.7461  -19.6394        97  No hotel found
# 565           motygino      RU  58.1831   94.7592        54  No hotel found
# 569           lycksele      SE  64.5954   18.6735       100  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_loc = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    alpha = 0.7,
    color = 'City',
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
hotel_loc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\util.py:230, in process_crs(crs)
#     229 try:
# --> 230     import cartopy.crs as ccrs
#     231     import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\ilian\OneDrive\Desktop\BC Work\python-api-challenge\Starter_Code\starter_code\VacationPy.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Configure the map plot
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> p2 = hotel_df.hvplot.points(
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     "Lng",
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     "Lat",
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     geo = True,
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     tiles = "OSM",
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     frame_width = 800,
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>     frame_height = 600,
#       <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>     size = "Humidity",
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a>     scale = 2,
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a>     alpha = 0.7,
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a>     color = 'City',
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a>     hover_cols = ["Hotel Name", "Country"]
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=15'>16</a> # Display the map
#      <a href='vscode-notebook-cell:/c%3A/Users/ilian/OneDrive/Desktop/BC%20Work/python-api-challenge/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a> p2
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\plotting\core.py:1612, in hvPlotTabular.points(self, x, y, **kwds)
#    1554 def points(self, x=None, y=None, **kwds):
#    1555     """
#    1556     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1557     geographic plots.
#    (...)
#    1610     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1611     """
# -> 1612     return self(x, y, kind="points", **kwds)
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\plotting\core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\plotting\core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\converter.py:396, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394 self.dynamic = dynamic
#     395 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396 self.crs = self._process_crs(data, crs) if self.geo else None
#     397 self.project = project
#     398 self.coastline = coastline
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\converter.py:650, in HoloViewsConverter._process_crs(self, data, crs)
#     647     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     649 try:
# --> 650     return process_crs(_crs)
#     651 except ValueError:
#     652     # only raise error if crs was specified in kwargs
#     653     if crs:
#
# File c:\Users\ilian\anaconda3\lib\site-packages\hvplot\util.py:234, in process_crs(crs)
#     232     import pyproj
#     233 except ImportError:
# --> 234     raise ImportError('Geographic projection support requires GeoViews, pyproj and cartopy.')
#     236 if crs is None:
#     237     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires GeoViews, pyproj and cartopy.
